# %% [markdown]
# <a href="https://colab.research.google.com/github/RAVULAAJAY/RAVULAAJAY/blob/Ajay/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
array=np.array([1,2,3])
print(array)
# Out:
# [1 2 3]

# %%
import numpy as np
array1= np.array([1,2,3])
array2= np.array([4,5,6])
print("Addition :"+str(array1+array2))
print("Subtraction :"+str(array1-array2))
print("Multiplication :"+str(array1*array2))
print("Division :"+str(array1/array2))
print("Power :"+str(array1**array2))
print("Modulus :"+str(array1%array2))
# Out:
# Addition :[5 7 9]
# Subtraction :[-3 -3 -3]
# Multiplication :[ 4 10 18]
# Division :[0.25 0.4  0.5 ]
# Power :[  1  32 729]
# Modulus :[1 2 3]

# %%
import numpy as np
array1= np.array([1,2,3])
array2= np.array([4,5,6])
print(np.sin(array1))
print(np.cos(array1))
print(np.tan(array1))
print(np.log(array1))
print(np.exp(array1))
print(np.log2(array1))
print(np.log(array1))
# Out:
# [0.84147098 0.90929743 0.14112001]
# [ 0.54030231 -0.41614684 -0.9899925 ]
# [ 1.55740772 -2.18503986 -0.14254654]
# [0.         0.69314718 1.09861229]
# [ 2.71828183  7.3890561  20.08553692]
# [0.        1.        1.5849625]
# [0.         0.69314718 1.09861229]
